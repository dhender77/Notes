# %% [markdown]
# <a href="https://colab.research.google.com/github/dhender77/Notes/blob/main/Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
#dataframes and series in pandas
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Index(['alt', 'bar', 'fri', 'hun', 'pat', 'price', 'rain', 'res', 'type',
#        'est'],
#       dtype='object')

# %%
restaurant_data = pd.read_csv('/content/drive/MyDrive/CS 167/restaurant.csv')
restaurant_data.head()
restaurant_data.shape

col = restaurant_data.columns
predictors = col[:10]
predictors
# Out:
# Index(['alt', 'bar', 'fri', 'hun', 'pat', 'price', 'rain', 'res', 'type',
#        'est'],
#       dtype='object')

# %%
titanic_data = pd.read_csv('/content/drive/MyDrive/CS 167/titanic.csv')
titanic_data.loc[880:887] #886 is name not number
titanic_data.iloc[880:887] #iloc gives index
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 881         0       3    male  33.0      0      0   7.8958        S   Third
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 883         0       2    male  28.0      0      0  10.5000        S  Second
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 880  woman       False  NaN  Southampton   yes  False
# 881    man        True  NaN  Southampton    no   True
# 882  woman       False  NaN  Southampton    no   True
# 883    man        True  NaN  Southampton    no   True
# 884    man        True  NaN  Southampton    no   True
# ...

# %%
subset = titanic_data.loc[880:885]
subset.head()
subset.iloc[0] #now subset, to get 880, need first row
# Out:
# survived                 1
# pclass                   2
# sex                 female
# age                   25.0
# sibsp                    0
# parch                    1
# fare                  26.0
# embarked                 S
# class               Second
# who                  woman
# adult_male           False
# deck                   NaN
# embark_town    Southampton
# alive                  yes
# alone                False
# Name: 880, dtype: object

# %%
prices = restaurant_data[['price','fri','target']] #subset with multiple columns included
prices
# Out:
#    price  fri target
# 0    $$$   No    Yes
# 1      $   No     No
# 2      $   No    Yes
# 3      $  Yes    Yes
# 4    $$$  Yes     No
# 5     $$   No    Yes
# 6      $   No     No
# 7     $$   No    Yes
# 8      $  Yes     No
# 9    $$$  Yes     No
# 10     $   No     No
# 11     $  Yes    Yes

# %%
titanic_data.head() #head prints first 5
ages = titanic_data['age']
titanic_subset = titanic_data[['survived', 'deck', 'sex', 'age']]
titanic_subset
# Out:
#      survived deck     sex   age
# 0           0  NaN    male  22.0
# 1           1    C  female  38.0
# 2           1  NaN  female  26.0
# 3           1    C  female  35.0
# 4           0  NaN    male  35.0
# ..        ...  ...     ...   ...
# 886         0  NaN    male  27.0
# 887         1    B  female  19.0
# 888         0  NaN  female   NaN
# 889         1    C    male  26.0
# 890         0  NaN    male  32.0
#
# [891 rows x 4 columns]

# %%
italian_rest = restaurant_data[restaurant_data['type'] == 'Thai']
italian_rest
# Out:
#     alt bar  fri  hun   pat price rain  res  type    est target
# 1   Yes  No   No  Yes  Full     $   No   No  Thai  30-60     No
# 3   Yes  No  Yes  Yes  Full     $   No   No  Thai  10-30    Yes
# 7    No  No   No  Yes  Some    $$  Yes  Yes  Thai   0-10    Yes
# 10   No  No   No   No  None     $   No   No  Thai   0-10     No

# %%
restaurant_data.head()
# Out:
#    alt  bar  fri  hun   pat price rain  res    type    est target
# 0  Yes   No   No  Yes  Some   $$$   No  Yes  French   0-10    Yes
# 1  Yes   No   No  Yes  Full     $   No   No    Thai  30-60     No
# 2   No  Yes   No   No  Some     $   No   No  Burger   0-10    Yes
# 3  Yes   No  Yes  Yes  Full     $   No   No    Thai  10-30    Yes
# 4  Yes   No  Yes   No  Full   $$$   No  Yes  French    >60     No

# %%
rainy_day = restaurant_data[restaurant_data['rain'] == 'Yes']
rainy_day
# Out:
#   alt  bar  fri  hun   pat price rain  res     type   est target
# 5  No  Yes   No  Yes  Some    $$  Yes  Yes  Italian  0-10    Yes
# 6  No  Yes   No   No  None     $  Yes   No   Burger  0-10     No
# 7  No   No   No  Yes  Some    $$  Yes  Yes     Thai  0-10    Yes
# 8  No  Yes  Yes   No  Full     $  Yes   No   Burger   >60     No

# %%
victims = titanic_data[titanic_data['survived']== 0]
victims
subset = victims['age']
subset
# Out:
# 0      22.0
# 4      35.0
# 5       NaN
# 6      54.0
# 7       2.0
#        ...
# 884    25.0
# 885    39.0
# 886    27.0
# 888     NaN
# 890    32.0
# Name: age, Length: 549, dtype: float64

# %%
titanic_data.age.mean()
# Out:
# 29.69911764705882

# %%
titanic_data.fare.median()
# Out:
# 14.4542

# %%
titanic_data.survived.sum()
# Out:
# 342

# %%
titanic_data.deck.unique() #gives all unique values in column
# Out:
# array([nan, 'C', 'E', 'G', 'D', 'A', 'B', 'F'], dtype=object)

# %%
titanic_data.groupby(['survived'])['age'].mean
# Out:
# <bound method GroupBy.mean of <pandas.core.groupby.generic.SeriesGroupBy object at 0x7f36b0d52e50>>

# %%
titanic_data.age.hist()

# %%
titanic_data.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200
